# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jahangir Khan**<br>
# Data Scientist

# %% [markdown]
# *I am interested in Data Science because I want to become a Data Scientist. I wish to become a Data Scientist because we are surrounded by Data and I love to make it meaningful for all.*

# %% [markdown]
# ### My code is going to produce output for a series of numbers get calculated by following mathematical rule.

# %%
2 + 2 * 2 + 6 / 3
# Out:
# 8.0

# %% [markdown]
# **Image from external source**
#
# <left> <img align="left" src = https://cdn.fansshare.com/image/ibm/ibm-logo-1201053674.jpg width = "200" height = "500" > </left> <br>
#
# <br>
#
# __[IBM website hyperlinked](https://www.ibm.com/us-en/)__
#
# ***
# <br>
#
# **Bulleted Items**
#  - Main bullet point
#      - Sub bullet point
#  - Main bullet point
#      - Sub bullet point
#
#  ***
#
#  **Numbered Items**
#  1. Numbered item
#      1. Substep
#      1. Substep
#  1. Numbered item
#  1. Numbered item
#
#  ***
#
#  ~~STRIKETHROUGH TEXT~~
